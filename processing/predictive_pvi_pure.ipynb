# %% [markdown]
# # Merge all Pure PVI datasets

# %% [markdown]
# Unfortunatley, data from 2002 on PVI is unavailable, so Data is limited to 2004-2021

# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df109 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_109.csv")

# %%
df109 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_109.csv")

# %%
df110 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_110.csv")

# %%
df111 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_111.csv")

# %%
df112 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_112.csv")

# %%
df113 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_113.csv")

# %%
df114 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_114.csv")

# %%
df115 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_115.csv")

# %%
df116 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_116.csv")

# %%
df117 = pd.read_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/pure_datasets/pure_117.csv")

# %%
df = pd.concat([df109,df110,df111,df112,df113,df114,df115,df116,df117])

# %%
df
# Out:
#      year  metric  is_GOP
# 0    2004   0.620       1
# 1    2004   0.630       1
# 2    2004   0.540       1
# 3    2004   0.660       1
# 4    2004   0.560       0
# 5    2004   0.750       1
# 6    2004   0.330       0
# 7    2004   0.640       1
# 8    2004   0.520       1
# 9    2004   0.590       1
# 10   2004   0.560       1
# 11   2004   0.360       0
# 12   2004   0.540       1
# 13   2004   0.620       1
# 14   2004   0.400       0
# 15   2004   0.510       1
# 16   2004   0.490       0
# 17   2004   0.500       0
# 18   2004   0.610       1
# 19   2004   0.500       0
# 20   2004   0.400       0
# 21   2004   0.630       1
# 22   2004   0.570       1
# 23   2004   0.610       1
# 24   2004   0.360       0
# 25   2004   0.290       0
# 26   2004   0.310       0
# 27   2004   0.140       0
# 28   2004   0.120       0
# 29   2004   0.410       0
# 30   2004   0.530       1
# 31   2004   0.280       0
# 32   2004   0.280       0
# 33   2004   0.320       0
# ...

# %%
import numpy as np
import plotnine as p9
from plotnine import ggplot, aes, facet_grid, labs, geom_point, geom_smooth
from sklearn.linear_model import LinearRegression as lm
import warnings
warnings.filterwarnings('ignore')

# %%
# Create a super simple scatterplot to examine the relationship between PVI and congressional district
(p9.ggplot(data=df, mapping=p9.aes(x='metric', y='is_GOP'))
 + p9.geom_point() 
 + labs(x='GOP Leaning of District', y='GOP Representation',color="",title="PVI Correlation"))
# Out:
# <ggplot: (8785268798597)>

# %%
#group by metric and average GOP seats
bm = df.groupby('metric').mean()
#this will not be produced into a dataset without aggregating all years, as 
bm = bm.reset_index()

# %%
#Plot averages
(p9.ggplot(data=bm, mapping=p9.aes(x='metric', y='is_GOP'))
 + p9.geom_point() 
 + labs(x='GOP Leaning of District', y="Share of GOP Representatives",color="",title="PVI Correlation"))
# Out:
# <ggplot: (8785268822489)>

# %%
#now lets limit the data to only the R+10 to D+10 range, calling it Limited Domain
ld = bm[bm["metric"] <= .6]
ld = ld[ld["metric"] >= .4]

# %%
#Plot averages
(p9.ggplot(data=ld, mapping=p9.aes(x='metric', y='is_GOP'))
 + p9.geom_point() 
 + geom_smooth(method = "lm", color = "red", se = False)
 + labs(x='GOP Leaning of District', y="Share of GOP Representatives",color="",title="PVI Correlation"))
# Out:
# <ggplot: (8785259908907)>

# %%
bm
# Out:
#      metric         year    is_GOP
# 0     0.060  2016.000000  0.000000
# 1     0.070  2008.333333  0.000000
# 2     0.080  2014.000000  0.000000
# 3     0.090  2009.428571  0.000000
# 4     0.100  2013.666667  0.000000
# 5     0.110  2010.000000  0.000000
# 6     0.120  2010.000000  0.000000
# 7     0.130  2014.285714  0.000000
# 8     0.140  2010.750000  0.000000
# 9     0.150  2009.142857  0.000000
# 10    0.160  2012.880000  0.000000
# 11    0.170  2010.625000  0.000000
# 12    0.180  2011.571429  0.000000
# 13    0.190  2010.235294  0.000000
# 14    0.200  2009.400000  0.000000
# 15    0.210  2015.166667  0.000000
# 16    0.220  2012.333333  0.000000
# 17    0.230  2014.600000  0.000000
# 18    0.240  2010.272727  0.000000
# 19    0.250  2012.190476  0.047619
# 20    0.260  2015.411765  0.000000
# 21    0.270  2012.606061  0.000000
# 22    0.280  2010.307692  0.000000
# 23    0.285  2015.000000  0.000000
# 24    0.290  2011.000000  0.000000
# 25    0.295  2018.000000  0.000000
# ...
