# %% [markdown]
# ## Setup

# %%
import requests
import pandas as pd
import os
import glob
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
#load the district files into a single dataframe
dist_path = "/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/full_districts"
all_files = sorted(glob.glob(dist_path + "/*.csv"))

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

districts = pd.concat(li, axis=0, ignore_index=False)

# %%
state_path = "/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/clean_data/state_pvi"
all_files = sorted(glob.glob(state_path + "/*.csv"))

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

all_states = pd.concat(li, axis=0, ignore_index=False)

# %%
red = [2010,2014]
blu = [2006,2008,2018]
districts["wave"] = "Neutral"
districts["wave"] = np.where(districts["year"].isin(red), 'Red', districts["wave"])
districts["wave"] = np.where(districts["year"].isin(blu), 'Blue', districts["wave"])

# %% [markdown]
# ## Bin the data and add the associated probabilities

# %% [markdown]
# After running multiple models on the data, it seemed that the raw probibilities (with some binning) were the best associated values. For all PVIs betwee D+5 and R+4 the probabilities speak for themselves and then for the more extreme ones are binned to remove noise

# %%
#split the dataframe into the smoothed bins
districts["bin"] = pd.cut(districts['metric'], 
    [0, .24, .42, .44, .45, .46, .47, .48, .49, .5,
        .51, .52, .53, .54, .57, .7, 1],
    labels=["D+26+","D+25 to D+8","D+7 to D+6","D+5","D+4","D+3","D+2","D+1",
        "EVEN","R+1","R+2","R+3","R+4","R+5 to R+7","R+8 to R+20","R+21+"])

# %%
def agg_probs(df):
    '''Aggregate probailites of GOP represenation by bin
    Args:
        a datdistricts with historical election results
    Returns:
        a dataframe aggregating the probabilities of GOP representation
    '''
    sort = df.groupby("bin").mean()
    sort = sort.sort_values(by="metric")
    return pd.DataFrame(sort.is_GOP).reset_index().rename(columns={"is_GOP":"prob_GOP"})

# %%
#aggregate probabilites of historical data
prob_gops = agg_probs(districts)
#attach associated probabilities
districts = pd.merge(districts,prob_gops)

# %% [markdown]
# # Compute Fairness

# %%
#create empty columns to fill in the state dataset
all_states["dist_loss"] = 0
all_states["porp_loss"] = 0

# %%
def fairness(year):
    '''A function to comupte the fairness metric for a given district
    Args: 
        a year
    Returns:
        a row in a state dataframe with a ton more columns showing fairness and displaying text
    '''
    #pull in datasets
    d = districts[districts["year"] == year]
    s = all_states[all_states["year"] == year]
    for ST in s.ST:
        st = d[d["ST"] == ST]
        st_avg = st.prob_GOP.mean()
        num_dist = len(st)
        act_num = st_avg * num_dist
        st_lean = s["metric"][s["ST"] == str(ST)]
        best_num = st_lean * num_dist
        diff_dist = (best_num-act_num)
        diff_pop = (diff_dist / num_dist)
        s.dist_loss[s["ST"] == ST] = diff_dist
        s.porp_loss[s["ST"] == ST] = diff_pop
        s["porp_text"] = np.where(s["porp_loss"] <= 0, '% Excluded, Against Dems', '% Excluded, Against GOP')
        s["porp_text"] = ((s["porp_loss"].abs().round(2))*100).fillna(0).astype(int).astype(str).str.rstrip(".0") + s["porp_text"]
        s["porp_text"] = np.where(s["porp_loss"].isna(), 'Incomplete Map', s["porp_text"])
        s["dist_text"] = np.where(s["dist_loss"] <= 0, ' Dem Districts Lost', ' GOP Districts Lost')
        s["dist_text"] = s["dist_loss"].abs().round(2).astype(str).str.rstrip(".0") + s["dist_text"]
        s["lean"] = np.where(s["porp_loss"] <= 0, 'Dems Excluded', 'GOP Excluded')
    return s

# %% [markdown]
# ## Produce Dataset for hexmap

# %%
#create the 118 dataframe for major displays
state_118 = fairness(2022)
#highlight single districts and preview maps
sds_118 = ["VT", "DE", "WY", "ND", "SD", "AK"]
prev_states = ["FL","LA","NH","MO"]
state_118['State Status'] = 'Multi-District'
state_118['State Status'] = np.where(state_118["ST"].isin(sds_118), 'Single District', state_118['State Status'])
state_118['State Status'] = np.where(state_118["ST"].isin(prev_states), 'Incomplete Map', state_118['State Status'])

# %%
#import hexagon locations and pair them
hexes = pd.read_excel("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/raw_data/hexmap_plots.xlsx")
hexes = hexes.rename(columns={"Abbreviation":"ST"})
hexes["row"] = hexes["Row"]*-1
hexes["column"] = hexes["Column"]
prez = state_118.merge(hexes, on="ST")
#invert hexes so map is upright
#drop and rename columns
prez = prez.drop(columns=["Row","Column","year"])
prez = prez.set_axis(['ST', 'PVI', 'Share GOP','dist_loss', 'porp_loss','Population Excluded', 'Districts Lost','Lean', 'State Status','State', 'row', 'column'], axis=1, inplace=False)

# %%
#perform fairness on the current congress
state_117 = fairness(2020)
ref_117 = state_117.merge(hexes, on="ST")
ref_117 = ref_117.drop(columns=["Row","Column","year"])
ref_117
ref_117 = ref_117.set_axis(['ST', 'PVI', 'Share GOP','dist_loss_117', 'porp_loss_117','Districts Lost (117th)', 'Population Excluded (117th)','Lean (117th)', 'State', 'row', 'column'], axis=1, inplace=False)

# %%
#attach 117th to it
add_to_prez = ref_117[["ST", "dist_loss_117", "porp_loss_117", "Population Excluded (117th)", "Districts Lost (117th)", 'Lean (117th)']]
prez = prez.merge(add_to_prez)
#Create an improvement metric
prez["Change"] = np.where(prez["porp_loss"] < abs(prez["porp_loss_117"]), 'Less Partisan Than 2020', 'More Partisan Than 2020')
prez["Change"] = np.where(prez["porp_loss"] == abs(prez["porp_loss_117"]), 'No Change Since 2020', prez["Change"])
prez["Change"] = np.where(prez["State Status"] == "Incomplete Map", 'Incomplete Map', prez["Change"])
prez['Districts Lost'] = np.where(prez["State Status"] == "Incomplete Map", 'Incomplete Map', prez['Districts Lost'])
prez['Population Excluded'] = np.where(prez["State Status"] == "Incomplete Map", 'Incomplete Map', prez['Population Excluded'])
prez['Districts Lost'] = np.where(prez["State Status"] == "Incomplete Map", 'Incomplete Map', prez['Districts Lost'])
prez['porp_loss'] = np.where(prez["State Status"] == "Incomplete Map", np.nan, prez['porp_loss'])

# %%
#fix Error States
prez["Population Excluded (117th)"][prez["ST"] == "NV"] = "Perfect Match"
#prez["Population Excluded"][prez["State"] == "Ohio (Overturned)"] = "20% Excluded, Against Dems"
#prez["Population Excluded"][prez["ST"] == "AZ"] = "10% Excluded, Against Dems"
#prez["Population Excluded"][prez["ST"] == "DE"] = "40% Excluded, Against GOP"
prez["Population Excluded (117th)"][prez["ST"] == "DE"] = "40% Excluded, Against GOP"

# %%
#import data from the previous dfs
#import strings from the old sheet, with headers and the two states
Cols = "ST,PVI,Share GOP,dist_loss,porp_loss,State,row,column,Population Excluded,pe_extra,Districts Lost,State Status,porp_loss_bin,Lean,dist_loss_117,porp_loss_117,Population Excluded (117th),pe_extra_117,Districts Lost (117th),State Status (117th),porp_loss_bin_117,Lean (117th),Change"
Cols = Cols.split(",")
XOH = "OH,R+6,0.56,-2.927585787909539,-0.19517238586063593,Ohio (Overturned),0,5.5,20% Excluded, Against Dems,2.93 Dem Districts Lost,Overturned Map,-2.0,Dems Excluded,-2.3115955431306805,-0.14447472144566753,14% Excluded, Against Dems,2.31 Dem Districts Lost,Multi-District,-1,Dems Excluded,More Partisan Than 2020"
XOH = pd.DataFrame(XOH.split(",")).T
XNC = "NC,R+3,0.53,-2.2426418948429436,-0.16018870677449598,North Carolina (Overturned),0,6.5,16% Excluded, Against Dems,2.24 Dem Districts Lost,Overturned Map,-2.0,Dems Excluded,-0.7676470696329112,-0.05904977458714701,6% Excluded, Against Dems,0.77 Dem Districts Lost,Multi-District,-1,Dems Excluded,More Partisan Than 2020"
XNC = pd.DataFrame(XNC.split(",")).T
#merge the two frames and fix column names
ovs = pd.concat([XOH,XNC])
ovs.columns=Cols
#merge comma deliniated cells back together
ovs["Population Excluded"] = ovs["Population Excluded"] + "," + ovs["pe_extra"]
ovs["Population Excluded (117th)"] = ovs["Population Excluded (117th)"] + ", " + ovs["pe_extra_117"]
#drop columns no longer in the prez
ovs = ovs.drop(columns=["pe_extra","pe_extra_117","porp_loss_bin", "State Status (117th)","porp_loss_bin_117"])
#merge back into the set
pd.concat([prez,ovs])
# Out:
#     ST   PVI Share GOP            dist_loss             porp_loss  \
# 0   AL  R+15      0.65             -1.22199              -0.17457
# 1   AK   R+9      0.59            -0.363509             -0.363509
# 2   AZ   R+3      0.53            -0.589545             -0.065505
# 3   AR  R+16      0.66             -1.22053             -0.305132
# 4   CA  D+14      0.36              10.3589               0.19921
# 5   CO   D+3      0.47             0.189334             0.0236667
# 6   CT   D+7      0.43               1.4191              0.283819
# 7   DE   D+6      0.44             0.395414              0.395414
# 8   FL   R+3      0.53             -2.17881                   NaN
# 9   GA   R+3      0.53             -1.51253             -0.108038
# 10  HI  D+15      0.35             0.691101              0.345551
# 11  ID  R+19      0.69            -0.573509             -0.286754
# 12  IL   D+7      0.43              3.12986              0.184109
# 13  IN  R+11      0.61             -1.37651             -0.152946
# 14  IA   R+6      0.56            -0.878844             -0.219711
# 15  KS  R+11      0.61             -1.07437             -0.268593
# 16  KY  R+16      0.66            -0.760859              -0.12681
# 17  LA  R+12      0.62             -1.09404                   NaN
# 18  ME   D+1      0.49             0.166158             0.0830792
# 19  MD  D+14      0.36              2.02863              0.253578
# 20  MA  D+14      0.36              3.16427              0.351585
# 21  MI   R+1      0.51            -0.356184            -0.0273988
# 22  MN   D+1      0.49            -0.345509            -0.0431887
# 23  MS  R+10       0.6            -0.511467             -0.127867
# 24  MO  R+11      0.61            -0.938484                   NaN
# 25  MT  R+11      0.61            -0.542901             -0.271451
# 26  NE  R+13      0.63            -0.465948             -0.155316
# 27  NV   R+0       0.5             0.200739             0.0501848
# 28  NH   R+0       0.5            0.0933621                   NaN
# 29  NJ   D+6      0.44              2.34836              0.195697
# 30  NM   D+3      0.47             0.664032              0.221344
# 31  NY  D+10       0.4              4.82031              0.185397
# 32  NC   R+3      0.53            -0.382799            -0.0273428
# 33  ND  R+20       0.7            -0.253509             -0.253509
# 34  OH   R+6      0.56               -2.352               -0.1568
# 35  OK  R+20       0.7             -1.36053             -0.272105
# 36  OR   D+6      0.44             0.963883              0.160647
# 37  PA   R+2      0.52            -0.323068             -0.019004
# 38  RI   D+8      0.42             0.648051              0.324025
# 39  SC   R+8      0.58             -1.71199              -0.24457
# 40  SD  R+16      0.66            -0.293509             -0.293509
# 41  TN  R+14      0.64             -2.01199             -0.223555
# 42  TX   R+5      0.55             -2.59064            -0.0681747
# 43  UT  R+13      0.63             -1.29404             -0.323509
# 44  VT  D+15      0.35             0.345551              0.345551
# 45  VA   D+2      0.48             0.517572              0.047052
# 46  WA   D+8      0.42               1.0101               0.10101
# 47  WV  R+23      0.73            -0.447018             -0.223509
# 48  WI   R+2      0.52              -1.1401             -0.142512
# 49  WY  R+26      0.76                -0.24                 -0.24
# 0   OH   R+6      0.56   -2.927585787909539  -0.19517238586063593
# 0   NC   R+3      0.53  -2.2426418948429436  -0.16018870677449598
#
#            Population Excluded            Districts Lost           Lean  \
# 0   17% Excluded, Against Dems   1.22 Dem Districts Lost  Dems Excluded
# 1   36% Excluded, Against Dems   0.36 Dem Districts Lost  Dems Excluded
# 2    7% Excluded, Against Dems   0.59 Dem Districts Lost  Dems Excluded
# 3   31% Excluded, Against Dems   1.22 Dem Districts Lost  Dems Excluded
# 4     2% Excluded, Against GOP  10.36 GOP Districts Lost   GOP Excluded
# 5     2% Excluded, Against GOP   0.19 GOP Districts Lost   GOP Excluded
# 6    28% Excluded, Against GOP   1.42 GOP Districts Lost   GOP Excluded
# 7     4% Excluded, Against GOP    0.4 GOP Districts Lost   GOP Excluded
# 8               Incomplete Map            Incomplete Map  Dems Excluded
# 9   11% Excluded, Against Dems   1.51 Dem Districts Lost  Dems Excluded
# 10   35% Excluded, Against GOP   0.69 GOP Districts Lost   GOP Excluded
# 11  28% Excluded, Against Dems   0.57 Dem Districts Lost  Dems Excluded
# 12   18% Excluded, Against GOP   3.13 GOP Districts Lost   GOP Excluded
# 13  15% Excluded, Against Dems   1.38 Dem Districts Lost  Dems Excluded
# 14  22% Excluded, Against Dems   0.88 Dem Districts Lost  Dems Excluded
# 15  27% Excluded, Against Dems   1.07 Dem Districts Lost  Dems Excluded
# 16  13% Excluded, Against Dems   0.76 Dem Districts Lost  Dems Excluded
# 17              Incomplete Map            Incomplete Map  Dems Excluded
# 18    8% Excluded, Against GOP   0.17 GOP Districts Lost   GOP Excluded
# 19   25% Excluded, Against GOP   2.03 GOP Districts Lost   GOP Excluded
# 20   35% Excluded, Against GOP   3.16 GOP Districts Lost   GOP Excluded
# 21   3% Excluded, Against Dems   0.36 Dem Districts Lost  Dems Excluded
# 22   4% Excluded, Against Dems   0.35 Dem Districts Lost  Dems Excluded
# 23  13% Excluded, Against Dems   0.51 Dem Districts Lost  Dems Excluded
# 24              Incomplete Map            Incomplete Map  Dems Excluded
# 25  27% Excluded, Against Dems   0.54 Dem Districts Lost  Dems Excluded
# 26  16% Excluded, Against Dems   0.47 Dem Districts Lost  Dems Excluded
# 27    5% Excluded, Against GOP    0.2 GOP Districts Lost   GOP Excluded
# 28              Incomplete Map            Incomplete Map   GOP Excluded
# 29    2% Excluded, Against GOP   2.35 GOP Districts Lost   GOP Excluded
# 30   22% Excluded, Against GOP   0.66 GOP Districts Lost   GOP Excluded
# 31   19% Excluded, Against GOP   4.82 GOP Districts Lost   GOP Excluded
# 32   3% Excluded, Against Dems   0.38 Dem Districts Lost  Dems Excluded
# 33  25% Excluded, Against Dems   0.25 Dem Districts Lost  Dems Excluded
# 34  16% Excluded, Against Dems   2.35 Dem Districts Lost  Dems Excluded
# 35  27% Excluded, Against Dems   1.36 Dem Districts Lost  Dems Excluded
# 36   16% Excluded, Against GOP   0.96 GOP Districts Lost   GOP Excluded
# 37   2% Excluded, Against Dems   0.32 Dem Districts Lost  Dems Excluded
# 38   32% Excluded, Against GOP   0.65 GOP Districts Lost   GOP Excluded
# 39  24% Excluded, Against Dems   1.71 Dem Districts Lost  Dems Excluded
# 40  28% Excluded, Against Dems   0.29 Dem Districts Lost  Dems Excluded
# 41  22% Excluded, Against Dems   2.01 Dem Districts Lost  Dems Excluded
# 42   7% Excluded, Against Dems   2.59 Dem Districts Lost  Dems Excluded
# 43  32% Excluded, Against Dems   1.29 Dem Districts Lost  Dems Excluded
# 44   35% Excluded, Against GOP   0.35 GOP Districts Lost   GOP Excluded
# 45    5% Excluded, Against GOP   0.52 GOP Districts Lost   GOP Excluded
# 46    1% Excluded, Against GOP   1.01 GOP Districts Lost   GOP Excluded
# 47  22% Excluded, Against Dems   0.45 Dem Districts Lost  Dems Excluded
# 48  14% Excluded, Against Dems   1.14 Dem Districts Lost  Dems Excluded
# 49  24% Excluded, Against Dems   0.24 Dem Districts Lost  Dems Excluded
# 0   20% Excluded, Against Dems   2.93 Dem Districts Lost  Dems Excluded
# 0   16% Excluded, Against Dems   2.24 Dem Districts Lost  Dems Excluded
#
#        State Status                        State row column  \
# 0    Multi-District                      Alabama  -6    7.5
# 1   Single District                       Alaska   0    0.5
# 2    Multi-District                      Arizona  -5      3
# 3    Multi-District                     Arkansas  -5      6
# 4    Multi-District                   California  -5      2
# 5    Multi-District                     Colorado  -4    3.5
# 6    Multi-District                  Connecticut  -3     11
# 7   Single District                     Delaware  -4    9.5
# 8    Incomplete Map                      Florida  -8    8.5
# 9    Multi-District                      Georgia  -7      8
# 10   Multi-District                       Hawaii  -8    0.5
# 11   Multi-District                        Idaho  -3      2
# 12   Multi-District                     Illinois  -3      6
# 13   Multi-District                      Indiana  -3      7
# 14   Multi-District                         Iowa  -3      5
# 15   Multi-District                       Kansas  -5      5
# 16   Multi-District                     Kentucky  -4    6.5
# 17   Incomplete Map                    Louisiana  -6    5.5
# 18   Multi-District                        Maine   0   11.5
# 19   Multi-District                     Maryland  -4    8.5
# 20   Multi-District                Massachusetts  -2   10.5
# 21   Multi-District                     Michigan  -2    7.5
# 22   Multi-District                    Minnesota  -2    4.5
# 23   Multi-District                  Mississippi  -6    6.5
# 24   Incomplete Map                     Missouri  -4    5.5
# 25   Multi-District                      Montana  -2    2.5
# 26   Multi-District                    Nebraska   -4    4.5
# 27   Multi-District                      Nevada   -4    2.5
# 28   Incomplete Map               New Hampshire   -1     11
# 29   Multi-District                  New Jersey   -3     10
# 30   Multi-District                  New Mexico   -6    3.5
# 31   Multi-District                    New York   -2    9.5
# 32   Multi-District              North Carolina   -5      9
# 33  Single District                North Dakota   -2    3.5
# 34   Multi-District                        Ohio   -3      8
# 35   Multi-District                    Oklahoma   -6    4.5
# 36   Multi-District                      Oregon   -4    1.5
# 37   Multi-District                 Pennsylvania  -3      9
# 38   Multi-District                Rhode Island   -2   11.5
# 39   Multi-District              South Carolina   -6    8.5
# 40  Single District                South Dakota   -3      4
# 41   Multi-District                   Tennessee   -5      7
# 42   Multi-District                       Texas   -7      4
# 43   Multi-District                        Utah   -5      4
# 44  Single District                     Vermont   -1     10
# 45   Multi-District                    Virginia   -5      8
# 46   Multi-District                  Washington   -2    1.5
# 47   Multi-District               West Virginia   -4    7.5
# 48   Multi-District                   Wisconsin   -2    5.5
# 49  Single District                      Wyoming  -3      3
# 0    Overturned Map            Ohio (Overturned)   0    5.5
# 0    Overturned Map  North Carolina (Overturned)   0    6.5
#
#           dist_loss_117         porp_loss_117  Population Excluded (117th)  \
# 0              -1.26848             -0.181212      1.27 Dem Districts Lost
# 1             -0.363509             -0.363509      0.36 Dem Districts Lost
# 2             0.0476862            0.00529847      0.05 GOP Districts Lost
# 3              -1.07641             -0.269102      1.08 Dem Districts Lost
# 4               10.0952              0.190476      10.1 GOP Districts Lost
# 5              0.475519             0.0679313      0.48 GOP Districts Lost
# 6               1.45923              0.291846      1.46 GOP Districts Lost
# 7              0.395414              0.395414    40% Excluded, Against GOP
# 8             -0.181692           -0.00672933      0.18 Dem Districts Lost
# 9              -1.51782             -0.108415      1.52 Dem Districts Lost
# 10             0.691101              0.345551      0.69 GOP Districts Lost
# 11            -0.573509             -0.286754      0.57 Dem Districts Lost
# 12              1.45799             0.0809993      1.46 GOP Districts Lost
# 13             -1.27889             -0.142098      1.28 Dem Districts Lost
# 14            -0.979662             -0.244916      0.98 Dem Districts Lost
# 15            -0.837985             -0.209496      0.84 Dem Districts Lost
# 16            -0.951467             -0.158578      0.95 Dem Districts Lost
# 17             -1.14498             -0.190829      1.14 Dem Districts Lost
# 18             0.166158             0.0830792      0.17 GOP Districts Lost
# 19              1.90424              0.238031       1.9 GOP Districts Lost
# 20              3.16427              0.351585      3.16 GOP Districts Lost
# 21             -1.25208            -0.0894345      1.25 Dem Districts Lost
# 22            -0.345509            -0.0431887      0.35 Dem Districts Lost
# 23            -0.511467             -0.127867      0.51 Dem Districts Lost
# 24            -0.860594             -0.107574      0.86 Dem Districts Lost
# 25            -0.343509             -0.343509      0.34 Dem Districts Lost
# 26            -0.655346             -0.218449      0.66 Dem Districts Lost
# 27            0.0172279            0.00430699                Perfect Match
# 28            0.0371955             0.0185978      0.04 GOP Districts Lost
# 29               1.4217              0.118475      1.42 GOP Districts Lost
# 30             0.407456              0.135819      0.41 GOP Districts Lost
# 31              2.42677             0.0898802      2.43 GOP Districts Lost
# 32            -0.767647            -0.0590498      0.77 Dem Districts Lost
# 33            -0.253509             -0.253509      0.25 Dem Districts Lost
# 34              -2.3116             -0.144475      2.31 Dem Districts Lost
# 35             -1.21641             -0.243282      1.22 Dem Districts Lost
# 36             0.307046             0.0614092      0.31 GOP Districts Lost
# 37            -0.620497            -0.0344721      0.62 Dem Districts Lost
# 38             0.648051              0.324025      0.65 GOP Districts Lost
# 39             -1.56788             -0.223982      1.57 Dem Districts Lost
# 40            -0.293509             -0.293509      0.29 Dem Districts Lost
# 41             -1.10498             -0.122775       1.1 Dem Districts Lost
# 42             -1.99818            -0.0555051         2 Dem Districts Lost
# 43             -1.14992              -0.28748      1.15 Dem Districts Lost
# 44             0.345551              0.345551      0.35 GOP Districts Lost
# 45             0.369764             0.0336149      0.37 GOP Districts Lost
# 46             0.937041             0.0937041      0.94 GOP Districts Lost
# 47            -0.763509             -0.254503      0.76 Dem Districts Lost
# 48             -1.26132             -0.157665      1.26 Dem Districts Lost
# 49                -0.24                 -0.24      0.24 Dem Districts Lost
# 0   -2.3115955431306805  -0.14447472144566753  14% Excluded,  Against Dems
# 0   -0.7676470696329112  -0.05904977458714701   6% Excluded,  Against Dems
#
#         Districts Lost (117th)   Lean (117th)                   Change
# 0   18% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 1   36% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 2     1% Excluded, Against GOP   GOP Excluded  Less Partisan Than 2020
# 3   27% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 4    19% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 5     7% Excluded, Against GOP   GOP Excluded  Less Partisan Than 2020
# 6    28% Excluded, Against GOP   GOP Excluded  Less Partisan Than 2020
# 7     4% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 8    1% Excluded, Against Dems  Dems Excluded           Incomplete Map
# 9   11% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 10   35% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 11  28% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 12    8% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 13  14% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 14  24% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 15  21% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 16  16% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 17  19% Excluded, Against Dems  Dems Excluded           Incomplete Map
# 18    8% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 19   24% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 20   35% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 21   9% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 22   4% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 23  13% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 24  11% Excluded, Against Dems  Dems Excluded           Incomplete Map
# 25  34% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 26  22% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 27     % Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 28    2% Excluded, Against GOP   GOP Excluded           Incomplete Map
# 29   12% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 30   14% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 31    9% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 32   6% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 33  25% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 34  14% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 35  24% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 36    6% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 37   3% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 38   32% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 39  22% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 40  28% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 41  12% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 42   6% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 43  28% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 44   35% Excluded, Against GOP   GOP Excluded     No Change Since 2020
# 45    3% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 46    9% Excluded, Against GOP   GOP Excluded  More Partisan Than 2020
# 47  25% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 48  16% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 49  24% Excluded, Against Dems  Dems Excluded  Less Partisan Than 2020
# 0      2.31 Dem Districts Lost  Dems Excluded  More Partisan Than 2020
# 0      0.77 Dem Districts Lost  Dems Excluded  More Partisan Than 2020

# %%
#first, fix the basic zero rounding erros
prez["Population Excluded"] = np.where(prez["Population Excluded"].str[0]=="%", ("0" + prez["Population Excluded"]), prez["Population Excluded"])

#identify possible string rounding errors in the master

# limit rows to those with a single digit reported percent
low_pct = prez[prez["Population Excluded"].str[1] == "%"]

# further limit to only those with possible rounding errors
low_pct = low_pct[low_pct["Population Excluded"].str[0].astype(int) < 5]

#now eliminate all correct rows that show a low percent 
low_pct = low_pct[round(abs(low_pct["porp_loss"]),2).astype(str).str[2] != "0"]

#All of the remaining rows have the rounding error that excludes the zero

# %%
def fix_round_ST(ST):
    '''A function that adds a zero to a string when the rounding excluded a 0
    Args:
        A state
    Returns:
        The associated row in the master dataframe now gets its deserved zero
    
    '''
    prez["Population Excluded"][prez["ST"] == ST] = (prez["Population Excluded"].str[0] + "0" + prez["Population Excluded"].str[1:])

# %%
#apply the fundtion to all erroneous year-state combinations
[fix_round_ST(ST) for ST in low_pct.ST]
# Out:
# [None, None, None, None]

# %%
#Export
prez.to_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/processed/2022_redraw_workbook.csv", index = False)

# %%
#make a quick state name key
abbrev = prez[["ST","State"]]

# %% [markdown]
# ## Produce dataset for Slider Bar

# %%
master = [fairness(year) for year in all_states.year.unique()]
master = pd.concat(master)

# %%
master = master.merge(abbrev, on="ST")

# %%
#create a column that verbally represents the congress
master["congress"] = (.5*(master["year"])-893).astype(str).str.rstrip(".0")
master["Period"] = master["congress"] + "th Congress (" + master["year"].astype(str) + ")"
master = master.replace('11th Congress (2006)','110th Congress (2006)')
master["congress"] = master["congress"].astype(int)

# %%
#catalogue Redistricting Events
master["event"] = "No Change Since Last Election"
master["event"] = np.where(master["year"] == 2004, '2004 Election and TX redraw', master["event"])
master["event"] = np.where(master["year"] == 2008, '2008 Election', master["event"])
master["event"] = np.where(master["year"] == 2012, '2012 Election and Redistricting', master["event"])
master["event"] = np.where(master["year"] == 2016, '2016 Election and FL/NC/VA redraw', master["event"])
master["event"] = np.where(master["year"] == 2018, 'PA Redraw', master["event"])
master["event"] = np.where(master["year"] == 2020, '2020 Election', master["event"])
master["event"] = np.where(master["year"] == 2022, '2022 Redistricting', master["event"])

# %%
#place identifying strings on maps not yet passed
master["State"] = np.where((master["ST"].isin(prev_states)) & (master["year"]==2022), (master["State"] + " (Anticipated)"), master["State"])
#master["ST"] = np.where((master["ST"].isin(prev_states)) & (master["year"]==2022), (master["ST"] + " (Anticipated)"), master["ST"])

# %%
#compute aggregate loss of districts and add it to the dataframe
# create dataset for total_dist_loss_lean with an abbreviated name
tdll = master.groupby(["year","lean"]).sum().reset_index().drop(["metric","congress","porp_loss"],axis=1)
tdll["ST"] = "US"

# create dataset for total_dist_loss_year with an abbreviated name
tdly = master.groupby(["year"]).sum().reset_index().drop(["metric","congress","porp_loss"],axis=1)

#incorporate into main 
tdll = tdll.rename(columns={"dist_loss":"dist_loss_agg"})
tdly = tdly.rename(columns={"dist_loss":"dist_loss_net"})
year_lean_measures = pd.merge(tdll,tdly,on="year")
agg_dl = year_lean_measures
agg_dl["key"] = agg_dl["year"].astype(str) + agg_dl["lean"].str[0]
agg_dl = agg_dl.drop(["year","lean","ST"], axis = 1)
master["key"] = master["year"].astype(str) + master["lean"].str[0]
master = pd.merge(master,agg_dl)
master = master.drop(["key"], axis = 1)

tdll.to_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/processed/total_dist_loss_lean.csv", index = False)

# %%
#first, fix the basic zero rounding erros
master["porp_text"] = np.where(master["porp_text"].str[0]=="%", ("0" + master["porp_text"]), master["porp_text"])

#identify possible string rounding errors in the master

# limit rows to those with a single digit reported percent
low_pct = master[master["porp_text"].str[1] == "%"]

# further limit to only those with possible rounding errors
low_pct = low_pct[low_pct["porp_text"].str[0].astype(int) < 5]

#now eliminate all correct rows that show a low percent 
low_pct = low_pct[round(abs(low_pct["porp_loss"]),2).astype(str).str[2] != "0"]

#All of the remaining rows have the rounding error that excludes the zero
#export a list of the year and state
low_pct["STyear"] = (low_pct["ST"]+low_pct["year"].astype(str))

# %%
def fix_round(STyear):
    '''A function that adds a zero to a string when the rounding excluded a 0
    Args:
        A year and a state
    Returns:
        The associated row in the master dataframe now gets its deserved zero
    
    '''
    ST = STyear[0:2]
    year = int(STyear[2:])
    master["porp_text"][(master["ST"] == ST) & (master["year"] == year)] = (master["porp_text"].str[0] + "0" + master["porp_text"].str[1:])

# %%
#apply the fundtion to all erroneous year-state combinations
[fix_round(STyear) for STyear in low_pct.STyear]
#check AL in 2004
master.head(1)
# Out:
#    year  ST  PVI  metric  dist_loss  porp_loss                   porp_text  \
# 0  2004  AL  R+8    0.58  -1.403359   -0.20048  20% Excluded, Against Dems
#
#                 dist_text           lean    State  congress  \
# 0  1.4 Dem Districts Lost  Dems Excluded  Alabama       109
#
#                   Period                        event  dist_loss_agg  \
# 0  109th Congress (2004)  2004 Election and TX redraw     -27.822022
#
#    dist_loss_net
# 0      -2.335246

# %%
master.to_csv("/Users/xavier/Desktop/DSPP/solo_projects/redistricting_project/processed/aggregated_fairness.csv", index = False)

# %% [markdown]
# ## Spare Code

# %%
tdll
# Out:
#     year           lean  dist_loss_agg  ST
# 0   2004  Dems Excluded     -27.822022  US
# 1   2004   GOP Excluded      25.486776  US
# 2   2006  Dems Excluded     -27.822022  US
# 3   2006   GOP Excluded      25.486776  US
# 4   2008  Dems Excluded     -30.783795  US
# 5   2008   GOP Excluded      24.889357  US
# 6   2010  Dems Excluded     -30.783795  US
# 7   2010   GOP Excluded      24.889357  US
# 8   2012  Dems Excluded     -34.761545  US
# 9   2012   GOP Excluded      28.313955  US
# 10  2014  Dems Excluded     -34.761545  US
# 11  2014   GOP Excluded      28.313955  US
# 12  2016  Dems Excluded     -33.286698  US
# 13  2016   GOP Excluded      26.089181  US
# 14  2018  Dems Excluded     -31.742438  US
# 15  2018   GOP Excluded      26.081737  US
# 16  2020  Dems Excluded     -27.691852  US
# 17  2020   GOP Excluded      26.774618  US
# 18  2022  Dems Excluded     -30.406724  US
# 19  2022   GOP Excluded      33.154753  US

# %%
pvi_118 = districts[districts["year"] == 2022]
df = districts[districts["year"] != 2022]
